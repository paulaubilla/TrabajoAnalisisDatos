# %% [markdown]
# <a href="https://colab.research.google.com/github/paulaubilla/TrabajoAnalisisDatos/blob/main/Trabajo_Analisis_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Código para Trabajo de Análisis de datos

# %%
import pandas as pd

df_casen2020= pd.read_stata("https://github.com/melanieoyarzun/taller_seriestiempo_IDS/blob/b0be4e78a8c7a738e41b284a65d350179abbda96/Data/casen_2020_ingresos.dta?raw=true")

df_casen2020.head(500)
# Out:
#             folio  o  id_persona              region   comuna    zona  expr  \
# 0    1.101100e+11  1           5  Región de Tarapacá  Iquique  Urbano    67
# 1    1.101100e+11  2           6  Región de Tarapacá  Iquique  Urbano    67
# 2    1.101100e+11  2          31  Región de Tarapacá  Iquique  Urbano    67
# 3    1.101100e+11  1          32  Región de Tarapacá  Iquique  Urbano    67
# 4    1.101100e+11  3          30  Región de Tarapacá  Iquique  Urbano    67
# ..            ... ..         ...                 ...      ...     ...   ...
# 495  1.101102e+11  1          83  Región de Tarapacá  Iquique  Urbano    57
# 496  1.101102e+11  4          86  Región de Tarapacá  Iquique  Urbano    57
# 497  1.101102e+11  5          87  Región de Tarapacá  Iquique  Urbano    57
# 498  1.101102e+11  2          88  Región de Tarapacá  Iquique  Urbano    57
# 499  1.101102e+11  6          84  Región de Tarapacá  Iquique  Urbano    57
#
# ...
